# %%
# !git clone --branch bit2 --depth 1 https://github.com/emanuelbertey/Evil-Inference-Code.git /content/evil_inference_bit2
# %cd /content/evil_inference_bit2

# %%
# !curl --proto '=https' --tlsv1.2 -sSf https://sh.rustup.rs | sh -s -- -y
import os
os.environ['PATH'] += ':/root/.cargo/bin'
# !rustc --version

# %%
# %cd /content/evil_inference_bit2/rust
# !cargo build --release
# !cargo run --release --bin transformer_chat_cuda -- input.txt
